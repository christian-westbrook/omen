# %% [markdown]
# upload final_features.csv and songs.csv

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import *

# %%
features = pd.read_csv('final_features.csv')
songs = pd.read_csv('songs.csv')

# %%
features.shape
# Out:
# (6372, 41)

# %%
data = features.drop(['tempo', 'mfcc_2', 'mfcc_3', 'mfcc_4', 'mfcc_5', 'mfcc_7', 'mfcc_8', 'mfcc_15', 'mfcc_17'], axis=1)

# %%
Y = data['number'].copy()
data = data.drop(['number'], axis = 1)

# %%
data = pd.get_dummies(data)

# %%
data.shape
# Out:
# (6372, 38)

# %%
xtrain, xtest, ytrain, ytest = model_selection.train_test_split(data, Y, test_size=0.1)

# %%
xtrain.shape
# Out:
# (5734, 38)

# %%
clf = neighbors.NearestNeighbors(n_neighbors=1)

# %%
clf.fit(xtrain)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                  radius=1.0)

# %%
distances, indices = clf.kneighbors(xtest.iloc[00].to_numpy().reshape(1, -1), n_neighbors=5, return_distance=True)

# %%
indices
# Out:
# array([[3220, 4294, 2905, 1214, 2129]])

# %%
xtest.iloc[0]
# Out:
# beats                    45.000000
# chroma_freq_0             0.406474
# chroma_freq_1             0.158789
# chroma_freq_2             0.111432
# chroma_freq_3             0.071924
# chroma_freq_4             0.222804
# chroma_freq_5             0.547803
# chroma_freq_6             0.214650
# chroma_freq_7             0.231362
# chroma_freq_8             0.141985
# chroma_freq_9             0.289409
# chroma_freq_10            0.162768
# chroma_freq_11            0.140060
# mfcc_0                 -274.753540
# mfcc_1                  119.002220
# mfcc_6                  -14.275587
# mfcc_9                   -5.788065
# mfcc_10                  -6.987465
# mfcc_11                  -4.969873
# mfcc_12                  -5.183269
# mfcc_13                  -4.573704
# mfcc_14                  -6.522708
# mfcc_16                  -0.743982
# mfcc_18                   5.031737
# mfcc_19                  11.147397
# rmse                      0.037428
# spectral_bandwidth     1936.185925
# spectral_centroid      1618.680437
# spectral_rolloff       3298.277194
# zero_crossing_rate       90.255371
# label_Electronic          0.000000
# label_Experimental        0.000000
# label_Folk                1.000000
# label_Hip-Hop             0.000000
# label_Instrumental        0.000000
# label_International       0.000000
# label_Pop                 0.000000
# label_Rock                0.000000
# Name: 2228, dtype: float64

# %%
import csv
with open('reco.csv', 'a+') as csv_file:
  fields = ['track', 'artist', 'genre']
  writer = csv.DictWriter(csv_file, fields)
  writer.writeheader()

# %%
for i in range(5):
  key = ytrain.iloc[indices[0][i]]
  for j in range(songs.shape[0]):
    if songs.iloc[j, 0] == key:
      with open('reco.csv', 'a+') as csv_file:
        writer = csv.writer(csv_file)
        writer.writerow([songs.iloc[j, 1], songs.iloc[j, 2], songs.iloc[j, 3]])

recommendations = pd.read_csv('reco.csv')
recommendations
# Out:
#                                track  ...          genre
# 0                       [conclusion]  ...  International
# 1                               Coco  ...  International
# 2                           Open Sea  ...     Electronic
# 3                                MIA  ...        Hip-Hop
# 4  Who Will Plant the Seeds of Peace  ...  International
#
# [5 rows x 3 columns]
